# %%
import numpy as np 
import yaml
import os 
import analyzer
import matplotlib.pyplot as plt

# %%
A = np.zeros([3,2]) 
B = np.ones([3,4])
print(np.hstack((A,B)))
# Out:
# [[0. 0. 1. 1. 1. 1.]
#  [0. 0. 1. 1. 1. 1.]
#  [0. 0. 1. 1. 1. 1.]]

# %%
##
repeat = 20

density_list = [100]
ratio_list = [0.0, 0.001, 0.01, 0.1, 1]

no_of_series_sim = len(density_list)*len(ratio_list)

# %%
'''
[Type of calculations]
- low density
low ratio 1
- rest
- activated
mid ratio 2
- rest
- activated
high ratio 3
- rest
- activated

- mid density 
low 4
- rest
- activated
mid 5
- rest
- activated
high 6
- rest
- activated

- high density 
low 7
- rest
- activated
mid 8
- rest
- activated
high 9
- rest
- activated
'''

ratiorx = np.zeros(5)
ratiory = np.zeros(5)
ratiorr = np.zeros(5)
ratiorxe = np.zeros(5)
ratiorye = np.zeros(5)
ratiorre = np.zeros(5)
ratiorxr = np.zeros(5)
ratioryr = np.zeros(5)
ratiorrr = np.zeros(5)
ratioax = np.zeros(5)
ratioay = np.zeros(5)
ratioar = np.zeros(5)
ratioaxe = np.zeros(5)
ratioaye = np.zeros(5)
ratioare = np.zeros(5)
ratioaxr = np.zeros(5)
ratioayr = np.zeros(5)
ratioarr = np.zeros(5)

ratiotx = np.zeros(5)
ratioty = np.zeros(5)
ratiotr = np.zeros(5)
ratiotxe = np.zeros(5)
ratiotye = np.zeros(5)
ratiotre = np.zeros(5)
ratiotxr = np.zeros(5)
ratiotyr = np.zeros(5)
ratiotrr = np.zeros(5)
count1 = 0

for i in [1,2,3,4,5]: # within low density 
    stats = analyzer.stats(repeat, no_of_series_sim, i)
    print(stats)
    
    ratiorx[count1] = stats['r_x_a']
    ratiory[count1] = stats['r_y_a']
    ratiorr[count1] = stats['r_r_a']
    ratiorxe[count1] = stats['r_x_e']
    ratiorye[count1] = stats['r_y_e']
    ratiorre[count1] = stats['r_r_e']
    ratiorxr[count1] = stats['r_x_r']
    ratioryr[count1] = stats['r_y_r']
    ratiorrr[count1] = stats['r_r_r']
    
    ratioax[count1] = stats['a_x_a']
    ratioay[count1] = stats['a_y_a']
    ratioar[count1] = stats['a_r_a']
    ratioaxe[count1] = stats['a_x_e']
    ratioaye[count1] = stats['a_y_e']
    ratioare[count1] = stats['a_r_e']
    ratioaxr[count1] = stats['a_x_r']
    ratioayr[count1] = stats['a_y_r']
    ratioarr[count1] = stats['a_r_r']
    
    ratiotx[count1] = stats['t_x_a']
    ratioty[count1] = stats['t_y_a']
    ratiotr[count1] = stats['t_r_a']
    ratiotxe[count1] = stats['t_x_e']
    ratiotye[count1] = stats['t_y_e']
    ratiotre[count1] = stats['t_r_e']
    ratiotxr[count1] = stats['t_x_r']
    ratiotyr[count1] = stats['t_y_r']
    ratiotrr[count1] = stats['t_r_r']
    
    count1 += 1
# Out:
# {'no_of_r_total': 1120, 'no_of_r_per': 56, 'no_of_a_total': 80, 'no_of_a_per': 4, 'r_x_a': 206.41282365151815, 'r_y_a': 38.42710285208055, 'r_r_a': 211.35846586362376, 'r_x_s': 56.94174553893738, 'r_y_s': 23.826339812240406, 'r_r_s': 56.74990540117183, 'r_x_e': 1.701460083339426, 'r_y_e': 0.71194807498282, 'r_r_e': 1.695727762812525, 'r_x_r': 214.1228996460066, 'r_y_r': 45.2143417783863, 'r_r_r': 218.8445860771213, 'a_x_a': 21.960568964481354, 'a_y_a': 4.715124502778053, 'a_r_a': 22.60444590964618, 'a_x_s': 4.578595135230345, 'a_y_s': 2.632329033477801, 'a_r_s': 4.62933072821168, 'a_x_e': 0.5119024981912447, 'a_y_e': 0.2943033329001341, 'a_r_e': 0.5175749099304959, 'a_x_r': 22.432791236404277, 'a_y_r': 5.400143999671505, 'a_r_r': 23.07361432184574, 't_x_a': 194.11600667238235, 't_x_s': 71.72563259419594, 't_x_e': 2.070540664302761, 't_x_r': 206.94344738954644, 't_y_a': 36.179637628793714, 't_y_s': 24.515821701223892, 't_y_e': 0.7077108129303241, 't_y_r': 43.703451724515155, 't_r_a': 
# ...

# %%
ratio = ['10','20','30','40','50']
ylabel = ['X-dir','Y-dir','Net']
x_pos = np.arange(len(ratio))
rtravelr = np.array([ratiorx,ratiory,ratiorr])
rtravelrmax = np.amax(rtravelr)
rtravela = np.array([ratioax,ratioay,ratioar])
rtravelamax = np.amax(rtravela)
rtravelt = np.array([ratiotx,ratioty,ratiotr])
rtraveltmax = np.amax(rtravelt)

rtravelrr = np.array([ratiorxr,ratioryr,ratiorrr])
rtravelrrmax = np.amax(rtravelrr)
rtraveltr = np.array([ratiotxr,ratiotyr,ratiotrr])
rtraveltrmax = np.amax(rtraveltr)

rerr_r = np.array([ratiorxe,ratiorye,ratiorre])
rerr_r_max = np.amax(rerr_r)
rerr_a = np.array([ratioaxe,ratioaye,ratioare])
rerr_a_max = np.amax(rerr_a)
rerr_t = np.array([ratiotxe,ratiotye,ratiotre])
rerr_t_max = np.amax(rerr_t)

# %%
print(rtravelrr)
# Out:
# [[214.12289965 219.29474732 225.24262295 230.89003371 236.14723605]
#  [ 45.21434178  49.31830903  54.05476209  58.96799778  65.89622348]
#  [218.84458608 224.77206634 231.63798587 238.30113812 245.16898124]]

# %%
fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1 
## resting ratio-based RMSD
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, rtravelrr[i], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('RMSD in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel('Number of Cells in 2nd box')
    ax.set_title(str(count)+'. Migration of Resting Cells \n with various degrees of paracrinic')
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtravelrrmax+50])
    # Build the plot
    count += 1 

# Save the figure and show
plt.tight_layout()
plt.show()

fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1 
## resting ratio-based RMSD
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, rtraveltr[i], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('RMSD in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel('Number of Cells in 2nd box')
    ax.set_title(str(count)+'. Migration of All Cells \n with various degrees of paracrinic')
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtraveltrmax+50])
    # Build the plot
    count += 1 

# Save the figure and show
plt.tight_layout()
plt.show()

# %%
ratio = ['20%','50%','80%']
cells = ['25','50','100']
x_pos = np.arange(len(ratio))

density = ['low density','mid density','high density']
proportion = ['low resting ratio','mid resting ratio','high resting ratio']

ylabel = ['X-dir','Y-dir','Net']
xlabel = ['proportion of resting cells','a number of cells']

status = ['Resting','Activated']

rtravelr = np.array([ratiorxr,ratioryr,ratiorrr])
rtravelrmax = np.amax(rtravelr)
rtravela = np.array([ratioaxr,ratioayr,ratioarr])
rtravelamax = np.amax(rtravela)

dtravelr = np.array([densrxr,densryr,densrrr])
dtravela = np.array([densaxr,densayr,densarr])

fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1 
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, rtravelr[i][0], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('RSMD. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel(xlabel[0])
    ax.set_title(str(count)+'. Migration of '+status[0]+' Cells with '+density[0])
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtravelrmax+25])
    # Build the plot
    count += 1 

        # Save the figure and show
plt.tight_layout()
plt.show()
        
fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1         
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, dtravelr[i][0], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('RSMD. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(cells)
    ax.set_xlabel(xlabel[1])
    ax.set_title(str(count)+'. Migration of '+status[0]+' Cells with '+proportion[0])
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtravelrmax+25])
    # Build the plot
    count += 1

        # Save the figure and show
plt.tight_layout()
plt.show()

# %%
ratio = ['20%','50%','80%']
cells = ['25','50','100']
x_pos = np.arange(len(ratio))

density = ['low density','mid density','high density']
proportion = ['low resting ratio','mid resting ratio','high resting ratio']

ylabel = ['X-dir','Y-dir','Net']
xlabel = ['proportion of resting cells','a number of cells']

status = ['Resting','Activated']

rtravelr = np.array([ratiorx,ratiory,ratiorr])
rtravelrmax = np.amax(rtravelr)
rtravela = np.array([ratioax,ratioay,ratioar])
rtravelamax = np.amax(rtravela)
rerr_r = np.array([ratiorxe,ratiorye,ratiorre])
rerr_r_max = np.amax(rerr_r)
rerr_a = np.array([ratioaxe,ratioaye,ratioare])
rerr_a_max = np.amax(rerr_a)

dtravelr = np.array([densrx,densry,densrr])
dtravela = np.array([densax,densay,densar])
derr_r = np.array([densrxe,densrye,densrre])
derr_a = np.array([densaxe,densaye,densare])


fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1 
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, rtravelr[i][2], yerr=rerr_r[i][2], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('Avg Dist. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel(xlabel[0])
    ax.set_title(str(count)+'. Migration of '+status[0]+' Cells with '+density[2])
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtravelrmax+rerr_r_max])
    # Build the plot
    count += 1 

        # Save the figure and show
plt.tight_layout()
plt.show()
        
fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1         
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, dtravelr[i][2], yerr=derr_r[i][2], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('Avg Dist. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(cells)
    ax.set_xlabel(xlabel[1])
    ax.set_title(str(count)+'. Migration of '+status[0]+' Cells with '+proportion[2])
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtravelrmax++rerr_r_max])
    # Build the plot
    count += 1

        # Save the figure and show
plt.tight_layout()
plt.show()

# %%
ratio = ['20%','50%','80%']
cells = ['25','50','100']
x_pos = np.arange(len(ratio))

density = ['low density','mid density','high density']
proportion = ['low resting ratio','mid resting ratio','high resting ratio']

ylabel = ['X-dir','Y-dir','Net']
xlabel = ['proportion of resting cells','a number of cells']

status = ['Resting','Activated']

rtravelr = np.array([ratiorx,ratiory,ratiorr])
rtravelrmax = np.amax(rtravelr)
rtravela = np.array([ratioax,ratioay,ratioar])
rtravelamax = np.amax(rtravela)
rerr_r = np.array([ratiorxe,ratiorye,ratiorre])
rerr_r_max = np.amax(rerr_r)
rerr_a = np.array([ratioaxe,ratioaye,ratioare])
rerr_a_max = np.amax(rerr_a)

dtravelr = np.array([densrx,densry,densrr])
dtravela = np.array([densax,densay,densar])
derr_r = np.array([densrxe,densrye,densrre])
derr_a = np.array([densaxe,densaye,densare])


fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1 
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, rtravelr[i][1], yerr=rerr_r[i][1], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('Avg Dist. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel(xlabel[0])
    ax.set_title(str(count)+'. Migration of '+status[0]+' Cells with '+density[1])
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtravelrmax+rerr_r_max])
    # Build the plot
    count += 1 

        # Save the figure and show
plt.tight_layout()
plt.show()
        
fig, axrr = plt.subplots(1,3, figsize=(20, 5), facecolor='w', edgecolor='k')
axrr = axrr.ravel()
count = 1         
for i in np.arange(3):
    ax = axrr[count-1]
    ax.bar(x_pos, dtravelr[i][1], yerr=derr_r[i][1], align='center', alpha=1, ecolor='black', capsize=10)
    ax.set_ylabel('Avg Dist. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(cells)
    ax.set_xlabel(xlabel[1])
    ax.set_title(str(count)+'. Migration of '+status[0]+' Cells with '+proportion[1])
    ax.yaxis.grid(True)
    ax.set_ylim([0,rtravelrmax++rerr_r_max])
    # Build the plot
    count += 1

        # Save the figure and show
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Generate data on commute times.
# 1 low ratio low density 
# 2 mid ratio low density 
# 3 high ratio low density 
# 4 low ratio mid density 
# 5 mid ratio mid density 
# 6 high ratio mid density
# 7 low ratio high density 
# 8 mid ratio high density 
# 9 high ratio high density

density = ['. low density','. mid density','. high density']
proportion = [' -20 % resting',' -50 % resting',' -80 % resting']
num = 1
k = 2
direction = [' in X',' in Y',' in R']



for k in np.arange(3):
    plt.figure(figsize=(20,15),dpi=120)
    figcount = 1
    count = 0
    for i in [1,2,3]:
        plt.subplot(3,3,figcount)
        figcount +=1
        rest, act = analyzer.distribution(repeat, no_of_series_sim, i)
        n, bins, patches = plt.hist(x=rest[k], bins=30, color='#0504aa',
                                    alpha=1, rwidth=0.5)
        plt.xlabel('Travel Dist.'+direction[k])
        plt.ylabel('Counts')
        plt.title(str(num)+density[0]+proportion[count])
        plt.grid(axis='y', alpha=0.75)
        maxfreq = n.max()
        # Set a clean upper y-axis limit.
        plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
        count += 1
        num += 1
        
#    plt.tight_layout()
#    plt.show()
#    plt.figure(figsize=(20,15))
    count = 0
    for i in [4,5,6]:
        plt.subplot(3,3,figcount)
        figcount +=1
        rest, act = analyzer.distribution(repeat, no_of_series_sim, i)
        n, bins, patches = plt.hist(x=rest[k], bins=30, color='#0504aa',
                                    alpha=1, rwidth=0.5)
        plt.xlabel('Travel Dist.'+direction[k])
        plt.ylabel('Counts')
        plt.title(str(num)+density[1]+proportion[count])
        plt.grid(axis='y', alpha=0.75)
        maxfreq = n.max()
        # Set a clean upper y-axis limit.
        plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
        count += 1
        num += 1

#    plt.tight_layout()
#    plt.show()
#    plt.figure(figsize=(20,15))
    count = 0
    for i in [7,8,9]:
        plt.subplot(3,3,figcount)
        figcount +=1
        rest, act = analyzer.distribution(repeat, no_of_series_sim, i)
        n, bins, patches = plt.hist(x=rest[k], bins=30, color='#0504aa',
                                    alpha=1, rwidth=0.5)
        plt.xlabel('Travel Dist.'+direction[k])
        plt.ylabel('Counts')
        plt.title(str(num)+density[2]+proportion[count])
        plt.grid(axis='y', alpha=0.75)
        maxfreq = n.max()
        # Set a clean upper y-axis limit.
        plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
        count += 1
        num += 1
        
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd

# Generate data on commute times.
# 1 low ratio low density 
# 2 mid ratio low density 
# 3 high ratio low density 
# 4 low ratio mid density 
# 5 mid ratio mid density 
# 6 high ratio mid density
# 7 low ratio high density 
# 8 mid ratio high density 
# 9 high ratio high density

density = ['. low density','. mid density','. high density']
proportion = [' -20 % resting',' -50 % resting',' -80 % resting']
num = 1
k = 2
direction = [' in X',' in Y',' in R']



for k in np.arange(3):
    count = 0
    for i in [1,2,3]:
        plt.figure(figsize=(4,3),dpi=100)
        rest, act = analyzer.distribution(repeat, no_of_series_sim, i)
        n, bins, patches = plt.hist(x=rest[k], bins=30, color='#0504aa',
                                    alpha=1, rwidth=0.5)
        plt.xlabel('Travel Dist.'+direction[k])
        plt.ylabel('Counts')
        plt.title(str(num)+density[0]+proportion[count])
        plt.grid(axis='y', alpha=0.75)
        maxfreq = n.max()
        # Set a clean upper y-axis limit.
        plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
        count += 1
        num += 1

    count = 0
    for i in [4,5,6]:
        plt.figure(figsize=(4,3),dpi=100)
        rest, act = analyzer.distribution(repeat, no_of_series_sim, i)
        n, bins, patches = plt.hist(x=rest[k], bins=30, color='#0504aa',
                                    alpha=1, rwidth=0.5)
        plt.xlabel('Travel Dist.'+direction[k])
        plt.ylabel('Counts')
        plt.title(str(num)+density[1]+proportion[count])
        plt.grid(axis='y', alpha=0.75)
        maxfreq = n.max()
        # Set a clean upper y-axis limit.
        plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
        count += 1
        num += 1

    count = 0
    for i in [7,8,9]:
        plt.figure(figsize=(4,3),dpi=100)
        rest, act = analyzer.distribution(repeat, no_of_series_sim, i)
        n, bins, patches = plt.hist(x=rest[k], bins=30, color='#0504aa',
                                    alpha=1, rwidth=0.5)
        plt.xlabel('Travel Dist.'+direction[k])
        plt.ylabel('Counts')
        plt.title(str(num)+density[2]+proportion[count])
        plt.grid(axis='y', alpha=0.75)
        maxfreq = n.max()
        # Set a clean upper y-axis limit.
        plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
        count += 1
        num += 1
# Out:
# /home/bending456/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# /home/bending456/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
count = 0
for i in [4,5,6]:
    rest, act = analyzer.distribution(5, no_of_series_sim, i)
    commutes = pd.Series(rest[k])
    commutes.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e',figsize=(10,7))
    plt.xlabel('Travel Dist.'+direction[k])
    plt.ylabel('Counts')
    plt.title(density[0]+proportion[count])
    plt.grid(axis='y', alpha=0.75)
    count += 1

# %%
count = 0
for i in [7,8,9]:
    rest, act = analyzer.distribution(5, no_of_series_sim, i)
    commutes = pd.Series(rest[k])
    commutes.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e',figsize=(10,7))
    plt.xlabel('Travel Dist.'+direction[k])
    plt.ylabel('Counts')
    plt.title(density[0]+proportion[count])
    plt.grid(axis='y', alpha=0.75)
    count += 1

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
plt.figure(figsize=(6,4),dpi=150)
n, bins, patches = plt.hist(x=rest[0], bins=30, color='#0504aa',
                            alpha=1, rwidth=0.5)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 10.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# ratio[x][y]: x indicates degree of density and y indicates degree of proportion of resting cells 
dades01 = ratiorx[0][0]
dades02 = ratiorx[0][1]
dades03 = [12,65,24,32,13,54,23,32,12,43]

df_3d = pd.DataFrame([dades01, dades02, dades03]).transpose()
colors = ['r','b','g','y','b','p']


fig = plt.figure(figsize=(6,6),dpi=150)
ax = fig.add_subplot(111, projection='3d')
z= list(df_3d)
yerr=np.array([10,10,10,10,10,10,10,10,10,10])

for n, i in enumerate(df_3d):
    xs = np.arange(len(df_3d[i]))
    ys = [i for i in df_3d[i]]
    zs = z[n]
    cs = colors[n]
    ax.bar(xs, ys, zs, zdir='y', color=cs, alpha=0.8)
    for i, j in enumerate(ys):
        ax.plot([xs[i], xs[i]], [zs, zs], [j+yerr[i], j-yerr[i]], marker="_", color=cs)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
'''
[Type of calculations]
- low density
low ratio 1
- rest
- activated
mid ratio 2
- rest
- activated
high ratio 3
- rest
- activated

- mid density 
low 4
- rest
- activated
mid 5
- rest
- activated
high 6
- rest
- activated

- high density 
low 7
- rest
- activated
mid 8
- rest
- activated
high 9
- rest
- activated
'''

ratiorx = []
ratiory = []
ratiorr = []
ratiorxe = []
ratiorye = []
ratiorre = []
ratioax = []
ratioay = []
ratioar = []
ratioaxe = []
ratioaye = []
ratioare = []

for i in [1,2,3]: # within low density 
    stats = analyzer.stats(repeat, no_of_series_sim, i)
    rx = stats['r_x_a']
    ry = stats['r_y_a']
    rr = stats['r_r_a']
    rxe = stats['r_x_e']
    rye = stats['r_y_e']
    rre = stats['r_r_e']
    ax = stats['a_x_a']
    ay = stats['a_y_a']
    ar = stats['a_r_a']
    axe = stats['a_x_e']
    aye = stats['a_y_e']
    are = stats['a_r_e']
    ratiorx.append(rx)
    ratiory.append(ry)
    ratiorr.append(rr)
    ratiorxe.append(rxe)
    ratiorye.append(rye)
    ratiorre.append(rre)
    ratioax.append(ax)
    ratioay.append(ay)
    ratioar.append(ar)
    ratioaxe.append(axe)
    ratioaye.append(aye)
    ratioare.append(are)

# %%
ratio = ['20%','50%','80%']
x_pos = np.arange(len(ratio))

ylabel = ['X-dir','Y-dir','Net']
status = ['Resting','Activated']

travelr = np.array([ratiorx,ratiory,ratiorr])
travela = np.array([ratioax,ratioay,ratioar])
err_r = np.array([ratiorxe,ratiorye,ratiorre])
err_a = np.array([ratioaxe,ratioaye,ratioare])


for i in np.arange(3):
    fig, ax = plt.subplots()
    ax.bar(x_pos, travelr[i], yerr=err_r[i], align='center', alpha=0.5, ecolor='black', capsize=10)
    ax.set_ylabel('Avg Dist. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel('proportion of resting cells')
    ax.set_title('Migration of '+status[0]+' Cells in low density')
    ax.yaxis.grid(True)
    # Build the plot


    # Save the figure and show
    plt.tight_layout()
    plt.show()

# %%
'''
[Type of calculations]
- low density
low ratio 1
- rest
- activated
mid ratio 2
- rest
- activated
high ratio 3
- rest
- activated

- mid density 
low 4
- rest
- activated
mid 5
- rest
- activated
high 6
- rest
- activated

- high density 
low 7
- rest
- activated
mid 8
- rest
- activated
high 9
- rest
- activated
'''

ratiorx = []
ratiory = []
ratiorr = []
ratiorxe = []
ratiorye = []
ratiorre = []
ratioax = []
ratioay = []
ratioar = []
ratioaxe = []
ratioaye = []
ratioare = []

for i in [4,5,6]: # within mid density 
    stats = analyzer.stats(repeat, no_of_series_sim, i)
    rx = stats['r_x_a']
    ry = stats['r_y_a']
    rr = stats['r_r_a']
    rxe = stats['r_x_e']
    rye = stats['r_y_e']
    rre = stats['r_r_e']
    ax = stats['a_x_a']
    ay = stats['a_y_a']
    ar = stats['a_r_a']
    axe = stats['a_x_e']
    aye = stats['a_y_e']
    are = stats['a_r_e']
    ratiorx.append(rx)
    ratiory.append(ry)
    ratiorr.append(rr)
    ratiorxe.append(rxe)
    ratiorye.append(rye)
    ratiorre.append(rre)
    ratioax.append(ax)
    ratioay.append(ay)
    ratioar.append(ar)
    ratioaxe.append(axe)
    ratioaye.append(aye)
    ratioare.append(are)

# %%
ratio = ['20%','50%','80%']
x_pos = np.arange(len(ratio))

ylabel = ['X-dir','Y-dir','Net']
status = ['Resting','Activated']

travelr = np.array([ratiorx,ratiory,ratiorr])
travela = np.array([ratioax,ratioay,ratioar])
err_r = np.array([ratiorxe,ratiorye,ratiorre])
err_a = np.array([ratioaxe,ratioaye,ratioare])


for i in np.arange(3):
    fig, ax = plt.subplots()
    ax.bar(x_pos, travelr[i], yerr=err_r[i], align='center', alpha=0.5, ecolor='black', capsize=10)
    ax.set_ylabel('Avg Dist. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel('proportion of resting cells')
    ax.set_title('Migration of '+status[0]+' Cells in mid density')
    ax.yaxis.grid(True)
    # Build the plot


    # Save the figure and show
    plt.tight_layout()
    plt.show()

# %%
'''
[Type of calculations]
- low density
low ratio 1
- rest
- activated
mid ratio 2
- rest
- activated
high ratio 3
- rest
- activated

- mid density 
low 4
- rest
- activated
mid 5
- rest
- activated
high 6
- rest
- activated

- high density 
low 7
- rest
- activated
mid 8
- rest
- activated
high 9
- rest
- activated
'''

ratiorx = []
ratiory = []
ratiorr = []
ratiorxe = []
ratiorye = []
ratiorre = []
ratioax = []
ratioay = []
ratioar = []
ratioaxe = []
ratioaye = []
ratioare = []

for i in [7,8,9]: # within mid density 
    stats = analyzer.stats(repeat, no_of_series_sim, i)
    rx = stats['r_x_a']
    ry = stats['r_y_a']
    rr = stats['r_r_a']
    rxe = stats['r_x_e']
    rye = stats['r_y_e']
    rre = stats['r_r_e']
    ax = stats['a_x_a']
    ay = stats['a_y_a']
    ar = stats['a_r_a']
    axe = stats['a_x_e']
    aye = stats['a_y_e']
    are = stats['a_r_e']
    ratiorx.append(rx)
    ratiory.append(ry)
    ratiorr.append(rr)
    ratiorxe.append(rxe)
    ratiorye.append(rye)
    ratiorre.append(rre)
    ratioax.append(ax)
    ratioay.append(ay)
    ratioar.append(ar)
    ratioaxe.append(axe)
    ratioaye.append(aye)
    ratioare.append(are)

# %%
ratio = ['20%','50%','80%']
x_pos = np.arange(len(ratio))

ylabel = ['X-dir','Y-dir','Net']
status = ['Resting','Activated']

travelr = np.array([ratiorx,ratiory,ratiorr])
travela = np.array([ratioax,ratioay,ratioar])
err_r = np.array([ratiorxe,ratiorye,ratiorre])
err_a = np.array([ratioaxe,ratioaye,ratioare])


for i in np.arange(3):
    fig, ax = plt.subplots()
    ax.bar(x_pos, travelr[i], yerr=err_r[i], align='center', alpha=0.5, ecolor='black', capsize=10)
    ax.set_ylabel('Avg Dist. in '+ylabel[i]+' (A)')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(ratio)
    ax.set_xlabel('proportion of resting cells')
    ax.set_title('Migration of '+status[0]+' Cells in high density')
    ax.yaxis.grid(True)
    # Build the plot


    # Save the figure and show
    plt.tight_layout()
    plt.show()

# %%
ratio = ['20%','50%','80%']
x_pos = np.arange(len(ratio))

ylabel = []
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, ratiorx, yerr=ratiorxe, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Avg Dist. in X-dir (A)')
ax.set_xticks(x_pos)
ax.set_xticklabels(ratio)
ax.set_ylabel('proportion of resting cells')
ax.set_title('Migration of Resting Cells in low density')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

# %%
print(stats_test)
# Out:
# {'no_of_r_total': 12, 'no_of_r_per': 6, 'no_of_a_total': 38, 'no_of_a_per': 19, 'r_x_a': 7.735532124837239, 'r_y_a': 2.2910324732462564, 'r_r_a': 8.730093010915967, 'r_x_s': 9.940343941806974, 'r_y_s': 9.940343941806974, 'r_r_s': 9.940343941806974, 'r_x_e': 2.8695301253198613, 'r_y_e': 2.8695301253198613, 'r_r_e': 2.8695301253198613, 'a_x_a': 0.38668933667634664, 'a_y_a': 0.26329140914113897, 'a_r_a': 0.49380000242888417, 'a_x_s': 0.16412391706992263, 'a_y_s': 0.16412391706992263, 'a_r_s': 0.16412391706992263, 'a_x_e': 0.026624415068630267, 'a_y_e': 0.026624415068630267, 'a_r_e': 0.026624415068630267}
